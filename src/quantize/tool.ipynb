# %%
import json

file = "data/data_collections/llama-13b/train.json"

with open(file, "r") as f:
    data = json.load(f)

print(data[0].keys())
# Out:
# dict_keys(['prompt', 'continuation', 'prefix', 'tokens', 'draft', 'log_p_1b', 'log_p_13b', 'p_acc'])
